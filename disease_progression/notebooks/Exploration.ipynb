# %%
import os

import pandas as pd

DATA_DIR = "../data"

# %%
os.listdir(os.path.join(DATA_DIR, "raw"))
# Out:
# ['patient_level_dp.csv']

# %%
df = pd.read_csv(os.path.join(DATA_DIR, "raw", "patient_level_dp.csv"))

# %%
df.dtypes
# Out:
# patid                    int64
# pracid                   int64
# usualgpstaffid         float64
# gender                  object
# yob                      int64
# mob                    float64
# emis_ddate              object
# regstartdate            object
# patienttypeid            int64
# regenddate              object
# acceptable               int64
# cprd_ddate              object
# obsdate_pef             object
# obsdate_ref             object
# obsdate                 object
# days_to_death          float64
# death_patient            int64
# death_event              int64
# days_in_observation    float64
# Phy_Age                  int64
# group                    int64
# dtype: object
