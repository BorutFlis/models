# %%
import os
import json
import sys

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

sys.path.append("../..")

DATA_DIR = "../data"

from early_diagnosis.data_loader.loader import load_data
from early_diagnosis.data_loader.source import EarlyDiagnosisSource
from abstract_models.imputation import median_imputer_missing

# %%
df = load_data(os.path.join(DATA_DIR, "raw", "train.csv"))

attr_selections = json.load(open(os.path.join(DATA_DIR, "expert_attr_selection.json")))

target = "Dia_HFD"

df = df.dropna(subset=target)
# Out:
# C:\Users\borut.flis\PycharmProjects\models\early_diagnosis\notebooks\../..\early_diagnosis\data_loader\loader.py:5: DtypeWarning: Columns (22,23,24,25,26,34,38,39,40,41,46,47,48,49,50,52,59,60,67,71,72,83,85,86,90,92,93,95,96,137,138,141,142,146,149,150,151,152,153,154,155,158,160,161,162,164,165,166,187,190,191,192,193,194,195,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,227,238,240,241,242,243,272,273,274,275,277,307,309,310,311,312,313,314,315,316,317,318,319,320) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_location, index_col=[0, 1])

# %%
df = df.loc[df["centre"].eq("UT")]

# %%
df[target].value_counts().sum()
# Out:
# 2658

# %%
imputer = median_imputer_missing
model = RandomForestClassifier()

pipeline = Pipeline(steps=[('preprocessor', imputer), ('classifier', model)])

# %%
data_source = EarlyDiagnosisSource(df, target=target)

# %%
X, y = data_source.xy()

attrs = list(set(attr_selections["expert"]).intersection(X.columns))
X = X.loc[:, attrs]

# %%
pipeline.fit(X,y)
# Out:
# C:\Users\borut.flis\AppData\Local\miniconda3\envs\stratifyHF\Lib\site-packages\sklearn\impute\_base.py:653: UserWarning: Skipping features without any observed values: ['Sym_PrE' 'Sym_PC']. At least one non-missing value is needed for imputation with strategy='most_frequent'.
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('both',
#                                                   MissingIndicator(features='all'),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002AFB8D4D290>),
#                                                  ('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002AFB8D83310>),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(drop='if_binary',
#                                                                                  handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002AFB8D4D310>)])),
#                 ('classifier', RandomForestClassifier())])

# %%
import mlflow
import mlflow.sklearn

mlflow.set_tracking_uri("http://127.0.0.1:5000")
mlflow.set_experiment("early_diagnosis_NT")

# Start an MLflow run
with mlflow.start_run() as run:
    # Log the model
    mlflow.sklearn.log_model(
        sk_model=pipeline,
        artifact_path="model",
        registered_model_name="EarlyDiagnosisUTHFD"  # Optional: Name in the model registry
    )

    # Log parameters or metrics if needed
    mlflow.log_param("model_type", "RandomForest")
    mlflow.log_param("preprocessing", "median_imputer_missing")
# Out:
# C:\Users\borut.flis\AppData\Local\miniconda3\envs\stratifyHF\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Successfully registered model 'EarlyDiagnosisUTHFD'.
# 2025/11/26 11:52:30 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation. Model name: EarlyDiagnosisUTHFD, version 1
# Created version '1' of model 'EarlyDiagnosisUTHFD'.
